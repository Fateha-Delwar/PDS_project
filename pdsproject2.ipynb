# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df1 = pd.read_csv('term-test-1-result.csv')
df2 = pd.read_csv('term-test-2-result.csv')
#term-test-1-result.csv

# %%
#merged dataframe
merged_df = pd.merge(df1, df2, on='Registration Number', how='inner')
print(merged_df.head())
# Out:
#   Registration Number    Name_x  TT-1 Marks    Name_y  TT-2 Marks
# 0             REG1000  Student1          20  Student1           9
# 1             REG1001  Student2          11  Student2           3
# 2             REG1002  Student3          14  Student3          10
# 3             REG1003  Student4          13  Student4           5
# 4             REG1004  Student5           7  Student5          15

# %%
# best term test marks
merged_df['Best Marks'] = merged_df[['TT-1 Marks', 'TT-2 Marks']].max(axis=1)

#  average term test marks
merged_df['Average Marks'] = merged_df[['TT-1 Marks', 'TT-2 Marks']].mean(axis=1)

print(merged_df.head())
# Out:
#   Registration Number    Name_x  TT-1 Marks    Name_y  TT-2 Marks  Best Marks  \
# 0             REG1000  Student1          20  Student1           9          20
# 1             REG1001  Student2          11  Student2           3          11
# 2             REG1002  Student3          14  Student3          10          14
# 3             REG1003  Student4          13  Student4           5          13
# 4             REG1004  Student5           7  Student5          15          15
#
#    Average Marks
# 0           14.5
# 1            7.0
# 2           12.0
# 3            9.0
# 4           11.0

# %%
merged_df = merged_df.drop(columns=['TT-1 Marks', 'TT-2 Marks'])

print(merged_df.head())
# Out:
#   Registration Number    Name_x    Name_y  Best Marks  Average Marks
# 0             REG1000  Student1  Student1          20           14.5
# 1             REG1001  Student2  Student2          11            7.0
# 2             REG1002  Student3  Student3          14           12.0
# 3             REG1003  Student4  Student4          13            9.0
# 4             REG1004  Student5  Student5          15           11.0

# %%
df3 = pd.read_csv('student_scores.csv')
df3.head()
# Out:
#   Registration Number  Attendance  Term Final Marks
# 0             REG1000           9                69
# 1             REG1001           8                95
# 2             REG1002           5                95
# 3             REG1003          10                59
# 4             REG1004          10                48

# %%
final_merged_df = pd.merge(merged_df, df3, on='Registration Number', how='inner')

final_merged_df['Final Marks'] = (final_merged_df['Term Final Marks'] * 0.7) + final_merged_df['Average Marks'] + final_merged_df['Attendance']

print(final_merged_df.head())
# Out:
#   Registration Number    Name_x    Name_y  Best Marks  Average Marks  \
# 0             REG1000  Student1  Student1          20           14.5
# 1             REG1001  Student2  Student2          11            7.0
# 2             REG1002  Student3  Student3          14           12.0
# 3             REG1003  Student4  Student4          13            9.0
# 4             REG1004  Student5  Student5          15           11.0
#
#    Attendance  Term Final Marks  Final Marks
# 0           9                69         71.8
# 1           8                95         81.5
# 2           5                95         83.5
# 3          10                59         60.3
# 4          10                48         54.6

# %%
final_merged_df.to_csv('final result.csv', index=False)

# %%
from google.colab import files
files.download('final result.csv')

# %%
from sklearn.cluster import KMeans

# %%
# Load the CSV file
df = pd.read_csv("final result.csv")
df
# Out:
#    Registration Number     Name_x     Name_y  Best Marks  Average Marks  \
# 0              REG1000   Student1   Student1          20           14.5
# 1              REG1001   Student2   Student2          11            7.0
# 2              REG1002   Student3   Student3          14           12.0
# 3              REG1003   Student4   Student4          13            9.0
# 4              REG1004   Student5   Student5          15           11.0
# 5              REG1005   Student6   Student6           9            6.5
# 6              REG1006   Student7   Student7          16           11.5
# 7              REG1007   Student8   Student8           9            5.0
# 8              REG1008   Student9   Student9           6            3.5
# 9              REG1009  Student10  Student10          20           14.0
# 10             REG1010  Student11  Student11          18           13.0
# 11             REG1011  Student12  Student12          20           19.0
# 12             REG1012  Student13  Student13          18           15.5
# 13             REG1013  Student14  Student14          13           11.5
# 14             REG1014  Student15  Student15          16           13.5
# 15             REG1015  Student16  Student16          19           11.0
# 16             REG1016  Student17  Student17           6            4.0
# 17             REG1017  Student18  Student18          19           12.5
# 18             REG1018  Student19  Student19          11            5.5
# 19             REG1019  Student20  Student20          20           12.0
# 20             REG1020  Student21  Student21          10            8.0
# 21             REG1021  Student22  Student22          20           11.5
# 22             REG1022  Student23  Student23          17           12.0
# 23             REG1023  Student24  Student24          14           10.0
# 24             REG1024  Student25  Student25           9            4.5
# 25             REG1025  Student26  Student26          20           18.0
# 26             REG1026  Student27  Student27          19           11.0
# 27             REG1027  Student28  Student28           9            5.5
# 28             REG1028  Student29  Student29          13            7.0
# 29             REG1029  Student30  Student30          17           11.0
# 30             REG1030  Student31  Student31          19           16.0
# 31             REG1031  Student32  Student32          15           11.0
# 32             REG1032  Student33  Student33          16            9.0
# 33             REG1033  Student34  Student34           4            4.0
# 34             REG1034  Student35  Student35          19           18.5
# 35             REG1035  Student36  Student36          13            7.5
# 36             REG1036  Student37  Student37          19           10.0
# 37             REG1037  Student38  Student38           9            8.5
# 38             REG1038  Student39  Student39          17           13.5
# 39             REG1039  Student40  Student40          15            9.0
# 40             REG1040  Student41  Student41          10            7.0
# 41             REG1041  Student42  Student42          16           14.0
# 42             REG1042  Student43  Student43          12            8.5
# 43             REG1043  Student44  Student44          16            9.0
# 44             REG1044  Student45  Student45           8            8.0
# 45             REG1045  Student46  Student46          16           15.5
# 46             REG1046  Student47  Student47          16            9.0
# 47             REG1047  Student48  Student48           7            5.5
# 48             REG1048  Student49  Student49           4            2.0
# 49             REG1049  Student50  Student50           0            0.0
#
#     Attendance  Term Final Marks  Final Marks
# 0            9                69         71.8
# 1            8                95         81.5
# 2            5                95         83.5
# 3           10                59         60.3
# 4           10                48         54.6
# 5            8                91         78.2
# 6            7                80         74.5
# 7            8                68         60.6
# 8            5                86         68.7
# 9            5                44         49.8
# 10           6                47         51.9
# 11           7               100         96.0
# 12           7                40         50.5
# 13           8                74         71.3
# 14           9                58         63.1
# 15           7                89         80.3
# 16           6                62         53.4
# 17          10                75         75.0
# 18           5                75         63.0
# 19           8                61         62.7
# 20          10                67         64.9
# 21           8                62         62.9
# 22           7                51         54.7
# 23           8                41         46.7
# 24           8                92         76.9
# 25           5                54         60.8
# 26           8                56         58.2
# 27           8                64         58.3
# 28           5                96         79.2
# 29           8                66         65.2
# 30          10                74         77.8
# 31           9                59         61.3
# 32           5                98         82.6
# 33           5                94         74.8
# 34           6                93         89.6
# 35          10                79         72.8
# 36          10                49         54.3
# 37           6                78         69.1
# 38           7                68         68.1
# 39           7                95         82.5
# 40           5                64         56.8
# 41           5                47         51.9
# 42           9                89         79.8
# 43          10                53         56.1
# 44           9                76         70.2
# 45           7                42         51.9
# 46           9                87         78.9
# 47           9                68         62.1
# 48           8                50         45.0
# 49          10                64         54.8

# %%
X = df[['Term Final Marks']]

kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict(X)

# %%
# Visualize the clusters
plt.figure(figsize=(8, 5))
plt.scatter(df['Name_x'], df['Term Final Marks'], c=df['Cluster'], cmap='viridis')
plt.xlabel('Student Name')
plt.ylabel('Final Marks')
plt.title('Clustering of Final Marks')
plt.xticks(rotation=90)
plt.colorbar(label='Cluster')
plt.tight_layout()
plt.show()
